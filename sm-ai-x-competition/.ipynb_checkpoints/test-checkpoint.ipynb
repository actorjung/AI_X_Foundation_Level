# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 데이터 불러오기 및 분석

# %%
df17 = pd.read_csv('test2017.csv', sep=',', index_col=0)
df18 = pd.read_csv('test2018.csv', sep=',', index_col=0)
df19 = pd.read_csv('test2019.csv', sep=',', index_col=0)
df20 = pd.read_csv('test2020.csv', sep=',', index_col=0)
df21 = pd.read_csv('test2021.csv', sep=',', index_col=0)

# %%
#아래로 합침
df_total = pd.concat([df17,df18,df19,df20,df21])
df_test = df21

# %%
df_total.shape
# Out:
# (43512, 31)

# %%
df_total.head()
# Out:
#       기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20170101      0  43922.2281       953.7652         627.7225
# 1  20170101      1  43763.4929       962.2909         633.3292
# 2  20170101      2  43561.5708       932.2939         613.6027
# 3  20170101      3  43928.9929       926.3617         609.7009
# 4  20170101      4  44150.2973       922.8893         607.4184
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         927.6134        2025.0630        2278.7336        1744.8161
# 1         970.6215        2045.7002        2412.6287        1765.7725
# 2         964.3505        2057.3601        2419.0941        1734.0569
# 3         983.2400        2100.5071        2480.1898        1780.3833
# 4         990.0534        2128.2729        2531.6549        1774.7853
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0        1713.6754  ...        2060.1511        1734.3805        1713.3332
# 1        1765.1171  ...        2037.5677        1745.5960        1735.4797
# 2        1746.3940  ...        2005.4838        1750.7594        1710.6116
# 3        1723.6640  ...        2044.6913        1777.4169        1718.1475
# 4        1752.0073  ...        2060.8824        1801.2144        1718.2957
#
#    여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 0        1754.6515        1636.4175        1521.3668        1728.0639
# 1        1700.9196        1619.3672        1474.8418        1661.3750
# 2        1660.6697        1660.9852        1511.4103        1635.0352
# 3        1678.9374        1626.8350        1516.5837        1665.8781
# 4        1678.6174        1640.9056        1513.5035        1653.2704
#
#    여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 0        1484.4518        1238.2606     3670.0451
# 1        1470.3009        1098.4788     3568.8258
# 2        1441.0173        1112.3632     3541.2620
# 3        1471.2127        1098.3154     3630.0822
# 4        1435.5180        1090.4059     3569.1653
#
# [5 rows x 31 columns]

# %%
df_total.tail()
# Out:
#          기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 8755  20211231     19  33304.5400       569.3452         374.9229
# 8756  20211231     20  33368.7201       599.9827         395.0698
# 8757  20211231     21  34083.1721       630.5049         415.1424
# 8758  20211231     22  34380.0806       618.6265         407.3311
# 8759  20211231     23  37074.2785       734.2128         483.3418
#
#       남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 8755         702.9942        1195.0912        1818.2627        1434.7351
# 8756         806.5718        1232.5401        1781.4567        1441.6411
# 8757         825.4794        1360.3197        1866.0852        1428.3237
# 8758         831.6651        1364.7723        1899.4216        1416.2191
# 8759         895.2420        1594.0355        2116.7695        1519.3632
#
#       남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 8755        1439.8129  ...        1870.7877        1628.8025        1474.3560
# 8756        1469.7313  ...        1890.1752        1598.9256        1469.9603
# 8757        1490.6164  ...        1964.4149        1560.5875        1404.8125
# 8758        1473.4710  ...        2017.0313        1573.9912        1507.6313
# 8759        1552.7195  ...        2100.5122        1637.1683        1570.8625
#
#       여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 8755        1136.8778        1399.4513        1262.9415        1342.7762
# 8756        1124.4243        1414.3330        1224.8609        1336.5298
# 8757        1174.9639        1477.2012        1250.2445        1336.1856
# 8758        1171.6865        1488.2721        1269.3231        1334.5079
# 8759        1251.8968        1514.6940        1379.1155        1319.0559
#
#       여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 8755        1058.0542         749.3935     2239.1210
# 8756        1056.6818         756.4905     2226.3545
# 8757        1042.3110         750.1392     2249.0323
# 8758        1045.8411         762.5466     2263.6665
# 8759        1138.3249         816.1801     2520.7282
#
# [5 rows x 31 columns]

# %%
df_test.head()
# Out:
#       기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20210101      0  38538.5993       785.1305         516.8260
# 1  20210101      1  38457.1528       824.8142         542.9229
# 2  20210101      2  38185.1451       843.5537         555.2454
# 3  20210101      3  38074.2836       830.9181         546.9359
# 4  20210101      4  38229.0027       842.3246         554.4371
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         816.9894        1572.9164        2240.8970        1632.0217
# 1         796.3712        1564.3204        2257.5202        1634.1890
# 2         795.1706        1571.2800        2249.8246        1626.4571
# 3         782.9169        1578.1156        2252.4146        1609.4993
# 4         778.0671        1574.4996        2223.7735        1615.1989
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0        1534.7635  ...        2169.0057        1665.5749        1700.9069
# 1        1506.8692  ...        2150.4378        1672.3825        1680.3394
# 2        1490.7254  ...        2135.2026        1658.6583        1666.0645
# 3        1491.9290  ...        2147.3304        1645.0832        1622.4721
# 4        1504.2698  ...        2150.8857        1653.0304        1635.3459
#
#    여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 0        1287.9528        1645.4256        1388.1055        1312.5581
# 1        1291.7540        1621.9283        1357.2407        1315.1492
# 2        1300.6873        1584.2217        1349.7012        1308.8865
# 3        1304.7938        1572.8782        1330.3253        1307.2665
# 4        1298.3282        1596.5642        1326.2002        1337.0726
#
#    여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 0        1176.5204         925.9878     2614.2247
# 1        1185.5568         907.0416     2607.8748
# 2        1164.7066         905.4539     2586.4604
# 3        1157.7801         909.6394     2577.8385
# 4        1167.3582         911.4016     2615.9563
#
# [5 rows x 31 columns]

# %%
df_test.tail()
# Out:
#          기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 8755  20211231     19  33304.5400       569.3452         374.9229
# 8756  20211231     20  33368.7201       599.9827         395.0698
# 8757  20211231     21  34083.1721       630.5049         415.1424
# 8758  20211231     22  34380.0806       618.6265         407.3311
# 8759  20211231     23  37074.2785       734.2128         483.3418
#
#       남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 8755         702.9942        1195.0912        1818.2627        1434.7351
# 8756         806.5718        1232.5401        1781.4567        1441.6411
# 8757         825.4794        1360.3197        1866.0852        1428.3237
# 8758         831.6651        1364.7723        1899.4216        1416.2191
# 8759         895.2420        1594.0355        2116.7695        1519.3632
#
#       남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 8755        1439.8129  ...        1870.7877        1628.8025        1474.3560
# 8756        1469.7313  ...        1890.1752        1598.9256        1469.9603
# 8757        1490.6164  ...        1964.4149        1560.5875        1404.8125
# 8758        1473.4710  ...        2017.0313        1573.9912        1507.6313
# 8759        1552.7195  ...        2100.5122        1637.1683        1570.8625
#
#       여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 8755        1136.8778        1399.4513        1262.9415        1342.7762
# 8756        1124.4243        1414.3330        1224.8609        1336.5298
# 8757        1174.9639        1477.2012        1250.2445        1336.1856
# 8758        1171.6865        1488.2721        1269.3231        1334.5079
# 8759        1251.8968        1514.6940        1379.1155        1319.0559
#
#       여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 8755        1058.0542         749.3935     2239.1210
# 8756        1056.6818         756.4905     2226.3545
# 8757        1042.3110         750.1392     2249.0323
# 8758        1045.8411         762.5466     2263.6665
# 8759        1138.3249         816.1801     2520.7282
#
# [5 rows x 31 columns]

# %%
df_total.to_csv('df_total.csv', index=False)

# %%
df_test.to_csv('df_test.csv',index=False)

# %% [markdown]
# # 데이터 전처리

# %%
df_total = pd.read_csv('df_total.csv')

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_total['기준일ID'] = pd.to_datetime(df_total['기준일ID'])

df_total['year'] = df_total['기준일ID'].dt.year
df_total['month'] = df_total['기준일ID'].dt.month
df_total['day'] = df_total['기준일ID'].dt.day

# %%
df_total
# Out:
#                               기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  \
# 0     1970-01-01 00:00:00.020170101      0  43922.2281       953.7652
# 1     1970-01-01 00:00:00.020170101      1  43763.4929       962.2909
# 2     1970-01-01 00:00:00.020170101      2  43561.5708       932.2939
# 3     1970-01-01 00:00:00.020170101      3  43928.9929       926.3617
# 4     1970-01-01 00:00:00.020170101      4  44150.2973       922.8893
# ...                             ...    ...         ...            ...
# 43507 1970-01-01 00:00:00.020211231     19  33304.5400       569.3452
# 43508 1970-01-01 00:00:00.020211231     20  33368.7201       599.9827
# 43509 1970-01-01 00:00:00.020211231     21  34083.1721       630.5049
# 43510 1970-01-01 00:00:00.020211231     22  34380.0806       618.6265
# 43511 1970-01-01 00:00:00.020211231     23  37074.2785       734.2128
#
#        남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 0             627.7225         927.6134        2025.0630        2278.7336
# 1             633.3292         970.6215        2045.7002        2412.6287
# 2             613.6027         964.3505        2057.3601        2419.0941
# 3             609.7009         983.2400        2100.5071        2480.1898
# 4             607.4184         990.0534        2128.2729        2531.6549
# ...                ...              ...              ...              ...
# 43507         374.9229         702.9942        1195.0912        1818.2627
# 43508         395.0698         806.5718        1232.5401        1781.4567
# 43509         415.1424         825.4794        1360.3197        1866.0852
# 43510         407.3311         831.6651        1364.7723        1899.4216
# 43511         483.3418         895.2420        1594.0355        2116.7695
#
#        남자30세부터34세생활인구수  남자35세부터39세생활인구수  ...  여자40세부터44세생활인구수  \
# 0            1744.8161        1713.6754  ...        1754.6515
# 1            1765.7725        1765.1171  ...        1700.9196
# 2            1734.0569        1746.3940  ...        1660.6697
# 3            1780.3833        1723.6640  ...        1678.9374
# 4            1774.7853        1752.0073  ...        1678.6174
# ...                ...              ...  ...              ...
# 43507        1434.7351        1439.8129  ...        1136.8778
# 43508        1441.6411        1469.7313  ...        1124.4243
# 43509        1428.3237        1490.6164  ...        1174.9639
# 43510        1416.2191        1473.4710  ...        1171.6865
# 43511        1519.3632        1552.7195  ...        1251.8968
#
#        여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0            1636.4175        1521.3668        1728.0639        1484.4518
# 1            1619.3672        1474.8418        1661.3750        1470.3009
# 2            1660.9852        1511.4103        1635.0352        1441.0173
# 3            1626.8350        1516.5837        1665.8781        1471.2127
# 4            1640.9056        1513.5035        1653.2704        1435.5180
# ...                ...              ...              ...              ...
# 43507        1399.4513        1262.9415        1342.7762        1058.0542
# 43508        1414.3330        1224.8609        1336.5298        1056.6818
# 43509        1477.2012        1250.2445        1336.1856        1042.3110
# 43510        1488.2721        1269.3231        1334.5079        1045.8411
# 43511        1514.6940        1379.1155        1319.0559        1138.3249
#
#        여자65세부터69세생활인구수  여자70세이상생활인구수  year  month  day
# 0            1238.2606     3670.0451  1970      1    1
# 1            1098.4788     3568.8258  1970      1    1
# 2            1112.3632     3541.2620  1970      1    1
# 3            1098.3154     3630.0822  1970      1    1
# 4            1090.4059     3569.1653  1970      1    1
# ...                ...           ...   ...    ...  ...
# 43507         749.3935     2239.1210  1970      1    1
# 43508         756.4905     2226.3545  1970      1    1
# 43509         750.1392     2249.0323  1970      1    1
# 43510         762.5466     2263.6665  1970      1    1
# 43511         816.1801     2520.7282  1970      1    1
#
# [43512 rows x 34 columns]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_total = df_total[['year','month','day','시간대구분','총생활인구수']]
df_total.rename(columns={'시간대구분':'hour'},inplace=True)
# Out:
# C:\Users\woosung\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_total
# Out:
#        year  month  day  hour      총생활인구수
# 0      1970      1    1     0  43922.2281
# 1      1970      1    1     1  43763.4929
# 2      1970      1    1     2  43561.5708
# 3      1970      1    1     3  43928.9929
# 4      1970      1    1     4  44150.2973
# ...     ...    ...  ...   ...         ...
# 43507  1970      1    1    19  33304.5400
# 43508  1970      1    1    20  33368.7201
# 43509  1970      1    1    21  34083.1721
# 43510  1970      1    1    22  34380.0806
# 43511  1970      1    1    23  37074.2785
#
# [43512 rows x 5 columns]

# %%
def MinMaxScaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    # 0으로 나누기 에러가 발생하지 않도록 매우 작은 값(1e-7)을 더해서 나눔
    return numerator / (denominator + 1e-7)

# %%
dfx = df_total[['총생활인구수']]
dfx = MinMaxScaler(dfx)
dfy = dfx[['총생활인구수']]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# dropna 하면 다 사라짐 이걸 각각 되게 해야할듯..
df_total = df_total.drop(['year','month','day','hour'], axis=1)

# %%
df_total
# Out:
#            총생활인구수
# 0      43922.2281
# 1      43763.4929
# 2      43561.5708
# 3      43928.9929
# 4      44150.2973
# ...           ...
# 43507  33304.5400
# 43508  33368.7201
# 43509  34083.1721
# 43510  34380.0806
# 43511  37074.2785
#
# [43512 rows x 1 columns]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_x['1h'] = df_x['총생활인구수'].shift(1)
df_x['1d'] = df_x['총생활인구수'].shift(24)
df_x['7d'] = df_x['총생활인구수'].shift(24*7)
df_x['28d'] = df_x['총생활인구수'].shift(24*28)
# Out:
# C:\Users\woosung\AppData\Local\Temp\ipykernel_26732\2567233065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x['1h'] = df_x['총생활인구수'].shift(1)
# C:\Users\woosung\AppData\Local\Temp\ipykernel_26732\2567233065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x['1d'] = df_x['총생활인구수'].shift(24)
# C:\Users\woosung\AppData\Local\Temp\ipykernel_26732\2567233065.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x['7d'] = df_x['총생활인구수'].shift(24*7)
# C:\Users\woosung\AppData\Local\Temp\ipykernel_26732\2567233065.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x['28d'] = df_x['총생활인구수'].shift(24*28)

# %%
df_x
# Out:
#            총생활인구수
# 41424  40495.8305
# 41425  40311.2269
# 41426  40272.7598
# 41427  40180.5495
# 41428  40346.9166
# ...           ...
# 43507  33304.5400
# 43508  33368.7201
# 43509  34083.1721
# 43510  34380.0806
# 43511  37074.2785
#
# [2088 rows x 1 columns]

# %%
#2021년11월 ~ 2021년12월
test_x = df_x

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total['1h'] = df_total['총생활인구수'].shift(1)
df_total['1d'] = df_total['총생활인구수'].shift(24)
df_total['7d'] = df_total['총생활인구수'].shift(24*7)
df_total['28d'] = df_total['총생활인구수'].shift(24*28)

# %%
df_total
# Out:
#            총생활인구수          1h          1d          7d         28d
# 0      43922.2281         NaN         NaN         NaN         NaN
# 1      43763.4929  43922.2281         NaN         NaN         NaN
# 2      43561.5708  43763.4929         NaN         NaN         NaN
# 3      43928.9929  43561.5708         NaN         NaN         NaN
# 4      44150.2973  43928.9929         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...
# 43507  33304.5400  33773.1695  34687.7515  35837.1203  36013.9567
# 43508  33368.7201  33304.5400  34728.1718  35867.0404  35383.6835
# 43509  34083.1721  33368.7201  35767.8222  36299.9836  35644.0511
# 43510  34380.0806  34083.1721  36193.0573  36409.8234  36039.1858
# 43511  37074.2785  34380.0806  38468.1344  39266.3421  39057.8215
#
# [43512 rows x 5 columns]

# %%
df_total = df_total.dropna()

# %%
df_total
# Out:
#            총생활인구수          1h          1d          7d         28d
# 672    39936.7089  39135.6296  39160.4917  47399.0967  43922.2281
# 673    39713.8903  39936.7089  39357.3787  47231.4592  43763.4929
# 674    39838.4925  39713.8903  39256.5031  47422.7713  43561.5708
# 675    40121.4797  39838.4925  39375.7449  47489.3674  43928.9929
# 676    40388.8146  40121.4797  39571.1807  47749.1020  44150.2973
# ...           ...         ...         ...         ...         ...
# 43507  33304.5400  33773.1695  34687.7515  35837.1203  36013.9567
# 43508  33368.7201  33304.5400  34728.1718  35867.0404  35383.6835
# 43509  34083.1721  33368.7201  35767.8222  36299.9836  35644.0511
# 43510  34380.0806  34083.1721  36193.0573  36409.8234  36039.1858
# 43511  37074.2785  34380.0806  38468.1344  39266.3421  39057.8215
#
# [42840 rows x 5 columns]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
x = df_total.iloc[ :,1:]
y = df_total.iloc[ :,:1]

# %%
x
# Out:
#                1h          1d          7d         28d
# 672    39135.6296  39160.4917  47399.0967  43922.2281
# 673    39936.7089  39357.3787  47231.4592  43763.4929
# 674    39713.8903  39256.5031  47422.7713  43561.5708
# 675    39838.4925  39375.7449  47489.3674  43928.9929
# 676    40121.4797  39571.1807  47749.1020  44150.2973
# ...           ...         ...         ...         ...
# 43507  33773.1695  34687.7515  35837.1203  36013.9567
# 43508  33304.5400  34728.1718  35867.0404  35383.6835
# 43509  33368.7201  35767.8222  36299.9836  35644.0511
# 43510  34083.1721  36193.0573  36409.8234  36039.1858
# 43511  34380.0806  38468.1344  39266.3421  39057.8215
#
# [42840 rows x 4 columns]

# %%
y
# Out:
#            총생활인구수
# 672    39936.7089
# 673    39713.8903
# 674    39838.4925
# 675    40121.4797
# 676    40388.8146
# ...           ...
# 43507  33304.5400
# 43508  33368.7201
# 43509  34083.1721
# 43510  34380.0806
# 43511  37074.2785
#
# [42840 rows x 1 columns]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
x = x.reset_index(drop=True)
y = y.reset_index(drop=True)

# %%
x.head()
# Out:
#            1h          1d          7d         28d
# 0  39135.6296  39160.4917  47399.0967  43922.2281
# 1  39936.7089  39357.3787  47231.4592  43763.4929
# 2  39713.8903  39256.5031  47422.7713  43561.5708
# 3  39838.4925  39375.7449  47489.3674  43928.9929
# 4  40121.4797  39571.1807  47749.1020  44150.2973

# %%
#2017년1월 ~ 2021년 10월 
train_x = x[:len(y)-1416]

# %%
train_x
# Out:
#                1h          1d          7d         28d
# 0      39135.6296  39160.4917  47399.0967  43922.2281
# 1      39936.7089  39357.3787  47231.4592  43763.4929
# 2      39713.8903  39256.5031  47422.7713  43561.5708
# 3      39838.4925  39375.7449  47489.3674  43928.9929
# 4      40121.4797  39571.1807  47749.1020  44150.2973
# ...           ...         ...         ...         ...
# 41419  35189.4563  36087.9937  35815.6482  36590.0838
# 41420  35708.4819  36339.3987  36009.3918  36551.4691
# 41421  35924.7026  36527.5722  36339.1032  37260.2154
# 41422  36597.7205  36940.6312  37097.1192  37391.9446
# 41423  37163.4665  40458.3040  40566.3709  40478.2807
#
# [41424 rows x 4 columns]

# %%
train_y = y[:len(y)-1416]

# %%
train_y
# Out:
#            총생활인구수
# 0      39936.7089
# 1      39713.8903
# 2      39838.4925
# 3      40121.4797
# 4      40388.8146
# ...           ...
# 41419  35708.4819
# 41420  35924.7026
# 41421  36597.7205
# 41422  37163.4665
# 41423  39853.9949
#
# [41424 rows x 1 columns]

# %%
#2021년11월 ~ 2021년12월
test_x = x[len(y)-1416:]

# %%
test_x
# Out:
#                1h          1d          7d         28d
# 41424  39853.9949  39865.1548  39738.4301  40495.8305
# 41425  39873.2794  39818.4645  39572.8291  40311.2269
# 41426  39797.9224  39863.9256  39462.3841  40272.7598
# 41427  39671.0867  39629.7011  39504.5727  40180.5495
# 41428  39720.9665  39955.2211  39643.7936  40346.9166
# ...           ...         ...         ...         ...
# 42835  33773.1695  34687.7515  35837.1203  36013.9567
# 42836  33304.5400  34728.1718  35867.0404  35383.6835
# 42837  33368.7201  35767.8222  36299.9836  35644.0511
# 42838  34083.1721  36193.0573  36409.8234  36039.1858
# 42839  34380.0806  38468.1344  39266.3421  39057.8215
#
# [1416 rows x 4 columns]

# %%
#2021년11월 ~ 2021년12월
test_y = y[len(y)-1416:]

# %%
test_x = test_x.iloc[ :,1:]
test_x
# Out:
#                1h          1d          7d         28d
# 42096         NaN         NaN         NaN         NaN
# 42097  39873.2794         NaN         NaN         NaN
# 42098  39797.9224         NaN         NaN         NaN
# 42099  39671.0867         NaN         NaN         NaN
# 42100  39720.9665         NaN         NaN         NaN
# ...           ...         ...         ...         ...
# 43507  33773.1695  34687.7515  35837.1203  36013.9567
# 43508  33304.5400  34728.1718  35867.0404  35383.6835
# 43509  33368.7201  35767.8222  36299.9836  35644.0511
# 43510  34083.1721  36193.0573  36409.8234  36039.1858
# 43511  34380.0806  38468.1344  39266.3421  39057.8215
#
# [1416 rows x 4 columns]

# %%
test_y
# Out:
#            총생활인구수
# 41424  39873.2794
# 41425  39797.9224
# 41426  39671.0867
# 41427  39720.9665
# 41428  39897.9873
# ...           ...
# 42835  33304.5400
# 42836  33368.7201
# 42837  34083.1721
# 42838  34380.0806
# 42839  37074.2785
#
# [1416 rows x 1 columns]

# %%
# CSV로 저장
train_x.to_csv('train_x.csv', index = False)
train_y.to_csv('train_y.csv', index = False)

# %%
test_x.to_csv('test_x.csv', index = False)
test_y.to_csv('test_y.csv', index = False)

# %% [markdown]
# # 모델링

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
print('훈련 데이터의 크기 :', train_x.shape, train_y.shape)
print('테스트 데이터의 크기 :', test_x.shape, test_y.shape)
# Out:
# 훈련 데이터의 크기 : (41424, 4) (41424, 1)
# 테스트 데이터의 크기 : (1416, 4) (1416, 1)

# %%
train_x = pd.read_csv("train_x.csv")
train_y = pd.read_csv("train_y.csv")

# %%
test_x = pd.read_csv("test_x.csv")
test_y = pd.read_csv("test_y.csv")

# %%
train_x = train_x.values
train_y = train_y.values

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
# 아래에 실습코드를 작성하세요.

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2
from math import sqrt

LR_reg = LinearRegression()
LR_reg.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
# Test 데이터로 성능을 평가해보세요.

y_pred_LR = LR_reg.predict(test_x)

print('LinearRegression')
print("Mean Squared Error : {0:.5f}".format(mse(test_y,y_pred_LR)))
print("Root Mean Squared Error : {0:.5f}".format(sqrt(mse(test_y,y_pred_LR))))
print("r2 : ", r2(test_y,y_pred_LR))
# Out:
# LinearRegression
# Mean Squared Error : 313499.22149
# Root Mean Squared Error : 559.91001
# r2 :  0.899668624486214
# C:\Users\woosung\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
# 아래에 실습코드를 작성하세요.

plt.figure(figsize=(40,10))
plt.plot(test_y, color='r')
plt.plot(y_pred_LR)

# %%
y_pred_LR
# Out:
# array([[39850.72593626],
#        [39826.25502193],
#        [39777.61566593],
#        ...,
#        [34205.87631037],
#        [34788.46413693],
#        [35958.56928518]])

# %%
result = pd.DataFrame(y_pred_LR)
result
# Out:
#                  0
# 0     39850.725936
# 1     39826.255022
# 2     39777.615666
# 3     39640.036463
# 4     39772.991708
# ...            ...
# 1411  34167.338297
# 1412  33855.341284
# 1413  34205.876310
# 1414  34788.464137
# 1415  35958.569285
#
# [1416 rows x 1 columns]

# %%
result.to_csv('result.csv')
