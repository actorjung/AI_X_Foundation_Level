# %% [markdown]
# # 안녕하세요^^
# ## '서울시 생활정보 기반 대중교통 수요 분석 ' 과정에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.
# ## "구별 업종 등록 데이터" 를 확인해 보도록 하겠습니다

# %% [raw]
# # 필요 라이브러리부터 설치합니다.
# %pip install pandas seaborn

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 기본/추가 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * business_type.csv
#
# [데이터 소개]
# * 서울 시 구별 등록 업종 상위 10개 데이터
#     * 택시운송업
#     * 한식일반음식점업
#     * 용달 화물자동차 운송업
#     * 부동산 중개 및 대리업
#     * 두발미용업
#     * 커피전문점
#     * 남녀용 겉옷 및 셔츠 도매업
#     * 기타주점업
#     * 일반 교과 학원
#     * 한식 육류요리 전문점
#
# [변수 소개]
# * 다수 업종 상위 1~10

# %% [markdown]
# ---

# %% [markdown]
# # 1.데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)
# * csv : pd.read_csv("파일이름. csv")
# * txt : pd.read_csv("파일이름. csv", sep="구분자")
# * xlsx : pd.read_excel('파일이름.xlsx')
# * pickle : pd.read_pickle("파일이름.pkl") <br>
#  [참고] pickle은 파이썬의 모든 객체를 파일로 저장할 수 있는 방법으로 DataFrame,List,Dict 등 모든 객체 저장 가능(특히 sklearn라이브러리를 통해 모델을 학습시키고, 저장할 때 많이 사용)

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * 1.4 business_type.csv
#
# [데이터 소개]
# * 서울시 업종 등록 데이터

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * '1.4 business_type.csv'파일을 'seoul_business' 변수에 저장하고 그 데이터를 확인하세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 ',' 입니다
#         * UTF-8 인코더를 사용해 주세요

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import pandas as pd
business_type = pd.read_csv('1.4 business_type.csv',sep=',', index_col = 0, encoding = 'UTF-8')

# %%
# 데이터 프레임의 Shape을 확인합니다.
business_type.shape
# Out:
# (451, 21)

# %% [markdown]
# ---

# %% [markdown]
# # 2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [실습문제2] 기본 정보 확인하기
# * 'seoul_moving' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head' 등 전부 활용해 보겠습니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
business_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 451 entries, 자치구 to 강동구
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   동             451 non-null    object
#  1   다수업종 상위10     451 non-null    object
#  2   다수업종 상위10.1   451 non-null    object
#  3   다수업종 상위10.2   451 non-null    object
#  4   다수업종 상위10.3   451 non-null    object
#  5   다수업종 상위10.4   451 non-null    object
#  6   다수업종 상위10.5   451 non-null    object
#  7   다수업종 상위10.6   451 non-null    object
#  8   다수업종 상위10.7   451 non-null    object
#  9   다수업종 상위10.8   451 non-null    object
#  10  다수업종 상위10.9   451 non-null    object
#  11  다수업종 상위10.10  451 non-null    object
#  12  다수업종 상위10.11  451 non-null    object
#  13  다수업종 상위10.12  451 non-null    object
#  14  다수업종 상위10.13  451 non-null    object
#  15  다수업종 상위10.14  451 non-null    object
#  16  다수업종 상위10.15  451 non-null    object
#  17  다수업종 상위10.16  451 non-null    object
# ...

# %%
business_type.head()
# Out:
#        동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3   다수업종 상위10.4  \
# 자치구
# 자치구    동     택시운송업       택시운송업  한식 일반 음식점업  한식 일반 음식점업  용달 화물자동차 운송업
# 자치구    동      사업체수        종사자수        사업체수        종사자수          사업체수
# 합계    합계    47,176      76,701      29,225     100,183        28,494
# 종로구   소계       215         215       1,548       5,912           618
# 종로구  사직동         7           7         230         982            12
#
#       다수업종 상위10.5   다수업종 상위10.6   다수업종 상위10.7 다수업종 상위10.8  ... 다수업종 상위10.10  \
# 자치구                                                        ...
# 자치구  용달 화물자동차 운송업  부동산 중개 및 대리업  부동산 중개 및 대리업       두발미용업  ...        커피전문점
# 자치구          종사자수          사업체수          종사자수        사업체수  ...         사업체수
# 합계         29,356        24,013        42,636      18,080  ...       16,255
# 종로구           646           549           889         261  ...          948
# 종로구            12            57            96          28  ...          124
#
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
business_type.describe()
# Out:
#           동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3 다수업종 상위10.4  \
# count   451       451         451         451         451         451
# unique  425       226         280         176         305         177
# top      소계        71          11          24         104          56
# freq     25         7           7          11           6           8
#
#        다수업종 상위10.5 다수업종 상위10.6 다수업종 상위10.7 다수업종 상위10.8  ... 다수업종 상위10.10  \
# count          451         451         451         451  ...          451
# unique         180         142         205         121  ...          131
# top             56          40          54          46  ...           13
# freq             9          11           9          12  ...           18
#
#        다수업종 상위10.11 다수업종 상위10.12 다수업종 상위10.13 다수업종 상위10.14 다수업종 상위10.15  \
# count           451          451          451          451          451
# unique          239           69          147          127          189
# ...

# %% [markdown]
# #### [실습문제3] 데이터 확인 및 처리
#
# * 데이터를 보았을때, 어느 데이터를 가져와야 할지 생각 해 봅시다.

# %%
# 사업체수와 종사자수를 다 합쳐버리자! 
df_1 = business_type.query('동=="소계"')
df_1[(df_1 == "-")] = 0
df_1
# Out:
# C:\Users\woosung\AppData\Local\Temp\ipykernel_2528\2564038000.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1[(df_1 == "-")] = 0
# C:\Users\woosung\AppData\Local\Temp\ipykernel_2528\2564038000.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1[(df_1 == "-")] = 0
#        동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3 다수업종 상위10.4  \
# 자치구
# 종로구   소계       215         215       1,548       5,912         618
# 중구    소계       230         235       1,588       6,414         300
# ...

# %%
df__1 = df_1.drop(['동'],axis=1)
df_2 = df__1.reset_index()
df_2
# Out:
#      자치구 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3 다수업종 상위10.4  \
# 0    종로구       215         215       1,548       5,912         618
# 1     중구       230         235       1,588       6,414         300
# 2    용산구       416         523         857       2,987         455
# 3    성동구     1,200       2,527         956       2,785       1,072
# 4    광진구     1,119       1,744         963       2,861         968
# 5   동대문구     1,546       2,093       1,236       3,566       1,431
# 6    중랑구     3,634       6,262         991       2,479       1,804
# 7    성북구     1,835       2,643         973       2,822       1,312
# 8    강북구     1,713       2,589         965       2,663       1,024
# 9    도봉구     2,993       5,783         672       2,009       1,571
# 10   노원구     4,114       6,074         866       2,650       1,730
# 11   은평구     3,108       4,430         881       2,585       1,340
# 12  서대문구     1,747       2,677         863       2,694         802
# ...

# %%
for column in df_2:
    for i in range (len(df_2[column])):
        df_2[column][i] = df_2[column][i].replace(',','')

# %%
df_s = df_2['자치구']
df_s
# Out:
# 0      종로구
# 1       중구
# 2      용산구
# 3      성동구
# 4      광진구
# 5     동대문구
# 6      중랑구
# 7      성북구
# 8      강북구
# 9      도봉구
# 10     노원구
# 11     은평구
# 12    서대문구
# 13     마포구
# 14     양천구
# 15     강서구
# 16     구로구
# 17     금천구
# 18    영등포구
# 19     동작구
# 20     관악구
# 21     서초구
# 22     강남구
# 23     송파구
# 24     강동구
# Name: 자치구, dtype: object

# %%
df_3 = df_2.drop(['자치구'],axis=1)

# %%
df_3
# Out:
#    다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3 다수업종 상위10.4 다수업종 상위10.5  \
# 0        215         215        1548        5912         618         646
# 1        230         235        1588        6414         300         333
# 2        416         523         857        2987         455         466
# 3       1200        2527         956        2785        1072        1161
# 4       1119        1744         963        2861         968         985
# 5       1546        2093        1236        3566        1431        1456
# 6       3634        6262         991        2479        1804        1877
# 7       1835        2643         973        2822        1312        1335
# 8       1713        2589         965        2663        1024        1030
# 9       2993        5783         672        2009        1571        1574
# 10      4114        6074         866        2650        1730        1736
# 11      3108        4430         881        2585        1340        1349
# ...

# %%
for column in df_2 :
    if column == '자치구':
        continue
    df_2[column] = df_2[column].astype['int']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
#       2 if column == '자치구':
#       3     continue
# ----> 4 df_2[column] = df_2[column].astype['int']
#
# TypeError: 'method' object is not subscriptable

# %%
# 사업체수 
df_4_1 = df_4[['다수업종 상위10','다수업종 상위10.2','다수업종 상위10.4','다수업종 상위10.6','다수업종 상위10.8','다수업종 상위10.10','다수업종 상위10.12','다수업종 상위10.14','다수업종 상위10.16','다수업종 상위10.18']]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# ...

# %%
# 종사자수 
df_4_2 = df_4[['다수업종 상위10.1','다수업종 상위10.3','다수업종 상위10.5','다수업종 상위10.7','다수업종 상위10.9','다수업종 상위10.11','다수업종 상위10.13','다수업종 상위10.15','다수업종 상위10.17','다수업종 상위10.19']]

# %%
# 해당 데이터프레임을 'df_seoul_business.csv' 파일로 저장하세요.

# %% [markdown]
# ---

# %% [markdown]
# # 3.데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='nanum')
sns.set(font="NanumGothicCoding",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [실습문제4] 데이터 분포 알아보기
# * 다양한 변수를 기준으로 그래프를 그려보고 인사이트를 도출해보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1. 
# 2.
# 3.

# %% [markdown]
# ---
